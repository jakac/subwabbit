# %% [markdown]
# # Explaining prediction
#
# This notebook shows how to visualize weights of learned Vowpal Wabbit model in human readable way.

# %% [markdown]
# At first, please train example model by running `tests/benchmarks/pretrain_model.py`.

# %%
import json
import random

from subwabbit import VowpalWabbitBaseFormatter, VowpalWabbitProcess

# %% [markdown]
# We will define formatter that converts feature dicts into Vowpal Wabbit's Input Format. Important part here is overriding method `parse_element`:

# %%
class BenchmarkFormatter(VowpalWabbitBaseFormatter):

    def get_common_line_part(self, common_features, debug_info=None):
        """
        Return part of VW line with features that are common for one call of predict/train.

        :param common_features: Features common for all items
        :param debug_info: Optional dict that can be filled by information useful for debugging
        :return: Part of line that is common for each item in one call. Returned string have to start with '|' symbol.
        """
        return ' '.join([
            '|d {}'.format(' '.join('d{}:{:.2f}'.format(k, v) for k, v in common_features['d'].items())),
            '|e {}'.format(' '.join('e{}:{:.2f}'.format(k, v) for k, v in common_features['e'].items())),
            '|f {}'.format(' '.join('f{}'.format(f) for f in common_features['f'])),
            '|g {}'.format(' '.join('g{}:{:.2f}'.format(k, v) for k, v in common_features['g'].items())),
            '|h h{}'.format(common_features['h']),
            '|i i{}'.format(common_features['i'])
        ])

    def get_item_line_part(self, common_features, item_features, debug_info=None):
        """
        Return part of VW line with features specific for each item/entity.

        :param common_features: Features common for all items
        :param item_features: Features for item
        :param debug_info: Optional dict that can be filled by information useful for debugging
        :return: Part of line that is specific for item. Returned string should not has any namespaces
                 or it has to start with '|' symbol.
        """
        return ' '.join([
            '|a a{}'.format(item_features['a']),
            '|b b{}'.format(item_features['b']),
            '|c {}'.format(' '.join('c{}'.format(c) for c in item_features['c']))
        ])
    
    def parse_element(self, element, feature_translator=None):
        """
        This method is supposed to translate namespace name and feature name to human readable form.

        For example, element can be "a_item_id^i123" and result can be ('Item ID', 'News of the day: ID of item is 123')

        :param element: namespace name and feature name, e.g. a_item_id^i123
        :param feature_translator: Any object that can help you with translation, e.g. some database connection
        :return: (human understandable namespace name, human understandable feature name)
        """
        if '^' in element:
            namespace, feature_name = element.split('^')
        else:
            namespace = None
            feature_name = element
        
        if namespace == 'a':
            return 'Item ID', feature_name
        elif namespace == 'b':
            return 'Item property', feature_name
        elif namespace == 'c':
            return 'Item tag', feature_name
        elif namespace in {'d', 'e', 'f', 'g', 'h', 'i'}:
            return 'Request feature {}'.format(namespace.upper()), feature_name
        return 'Unknown feature {}'.format(namespace), feature_name

# %% [markdown]
# Then we instantiate Vowpal Wabbit process in audit mode.

# %%
formatter = BenchmarkFormatter()

model = VowpalWabbitProcess(
    formatter=formatter,
    vw_args=['-i', '../tests/benchmarks/model.vw'],
    audit_mode=True
)

# %% [markdown]
# Load some example features used in training model.

# %%
with open('../tests/benchmarks/requests.json') as f:
    requests = json.load(f)
with open('../tests/benchmarks/items.json') as f:
    items = json.load(f)

# %%
requests[0]
# Out:
# {'d': {},
#  'e': {},
#  'f': [],
#  'g': {'0dceb': 0.0027175746,
#   '1b7db': 0.0058458746,
#   '1e5ee': 0.0095307727,
#   '3a5f9': 0.0051918319,
#   '3bb58': 0.0030790292,
#   '45e03': 0.0025652254,
#   '4e455': 0.0111844653,
#   '57ebe': 0.0632717824,
#   '5e800': 0.0039546815,
#   '61180': 0.08349630250000001,
#   '624c5': 0.0076227528,
#   '73c83': 0.0026011386,
#   '78bbb': 0.150152073,
#   '7a677': 0.027146533100000002,
#   '856b1': 0.0051462646,
#   '8a66c': 0.006105892700000001,
#   '8ea1e': 0.0044644849,
#   '95766': 0.0048473435,
#   '9a32e': 0.0319729173,
#   '9ca90': 0.0069261085,
#   'a896b': 0.034539330300000004,
#   'b1e29': 0.0267581808,
#   'b4e62': 0.0205558879,
#   'b8e32': 0.017786406600000002,
#   'bdcb5': 0.1895181926,
#   'bdffc': 0.005942737500000001,
#   'c7495': 0.018038030400000002,
#   'c7bc7': 0.0151302432,
#   'c8829': 0.0032719483000000003,
#   'ccbb0': 0.0045337064,
#   'cdf49': 0.1394195405,
#   'd299a': 0.0104898966,
#   'e3743': 0.0469601029,
#   'f0128': 0.0043615247,
#   'f2dff': 0.0025652254,
#   'f9d39': 0.013900131900000001,
#   'fdec5': 0.008405865},
#  'h': '80061',
#  'i': 'c51ce'}

# %%
items[0]
# Out:
# {'a': 5741672901246703469, 'b': 39, 'c': [272, 10]}

# %% [markdown]
# Translate features into Vowpal Wabbit Input Format:

# %%
vw_line = formatter.get_vw_line(
    common_line_part=formatter.get_common_line_part(
        common_features=requests[random.randint(0, len(requests) - 1)]
    ),
    item_line_part=formatter.get_item_line_part(
        common_features=None,
        item_features=items[random.randint(0, len(items) - 1)]
    )
)

# %%
vw_line
# Out:
# '|d d374:0.17 d30:0.33 d266:0.17 d10:0.17 d53:0.17 |e e243:0.10 e51:0.10 e81:0.10 e164:0.10 e262:0.20 e429:0.10 e404:0.30 |f f2099715132508010584 f16347014626840415796 f5460200835877347079 f15901405900115419411 f2868430111867810921 f16392528256463451848 f5035192394965831262 f16445323628105595511 f16833477272344963305 f646294422815440915 |g g5e800:0.01 g8a2bd:0.05 gd9b64:0.02 g5a110:0.01 gccbb0:0.28 gcdf49:0.00 g75702:0.02 gc8829:0.05 g856b1:0.02 gb6297:0.02 gbdcb5:0.01 geaf90:0.00 g69ddb:0.01 gd787f:0.02 gc1e24:0.01 gfd512:0.02 g1a16a:0.02 g1b7db:0.09 g57ebe:0.01 g8eab9:0.01 g8a66c:0.01 gcb163:0.01 gfc79f:0.00 gdeb91:0.00 gd299a:0.10 gaf8a2:0.00 g9a32e:0.01 g1e5ee:0.00 gf0d48:0.02 gde9d9:0.03 gc7495:0.00 g89fee:0.07 g3bb58:0.02 g8c856:0.00 gb9ea0:0.01 g5b708:0.03 |h h69691 |i iaab32 |a a1760747215799128656 |b b272 |c c49 c22'

# %% [markdown]
# Let Vowpal Wabbit explains how it calculated score. Be aware when using link function like `logistic`, the you have to pass `link_function=True`.

# %%
score, explanation_string = model.explain_vw_line(vw_line, link_function=True)

# %%
score
# Out:
# -0.130156

# %% [markdown]
# Explanation string looks like this:

# %%
print(explanation_string[:150] + '...')
# Out:
# b^b272*e^e164:29794476:0.1:-0.300118@0	a^a1760747215799128656*e^e164:18321926:0.1:-0.300118@0	c^c49*h^h69691:18276055:1:0.0167762@0	c^c49*f^f163470146...

# %% [markdown]
# Let formatter to parse it:

# %%
formatter.get_human_readable_explanation_html(explanation_string)
# Out:
# [{'hashindex': '29794476',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e164')],
#   'original_feature_name': 'b^b272*e^e164',
#   'potential': -0.0300118,
#   'relative_potential': 0.04402731723192768,
#   'value': 0.1,
#   'weight': -0.300118},
#  {'hashindex': '18321926',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature E', 'e164')],
#   'original_feature_name': 'a^a1760747215799128656*e^e164',
#   'potential': -0.0300118,
#   'relative_potential': 0.04402731723192768,
#   'value': 0.1,
#   'weight': -0.300118},
#  {'hashindex': '18276055',
#   'names': [('Item tag', 'c49'), ('Request feature H', 'h69691')],
#   'original_feature_name': 'c^c49*h^h69691',
#   'potential': 0.0167762,
#   'relative_potential': 0.024610689107160022,
#   'value': 1.0,
#   'weight': 0.0167762},
#  {'hashindex': '15669716',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f16347014626840415796')],
#   'original_feature_name': 'c^c49*f^f16347014626840415796',
#   'potential': -0.0163225,
#   'relative_potential': 0.023945111106902603,
#   'value': 1.0,
#   'weight': -0.0163225},
#  {'hashindex': '32988148',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f15901405900115419411')],
#   'original_feature_name': 'b^b272*f^f15901405900115419411',
#   'potential': -0.0146799,
#   'relative_potential': 0.021535416543925226,
#   'value': 1.0,
#   'weight': -0.0146799},
#  {'hashindex': '6814558',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f2099715132508010584')],
#   'original_feature_name': 'b^b272*f^f2099715132508010584',
#   'potential': -0.0141378,
#   'relative_potential': 0.020740155724133413,
#   'value': 1.0,
#   'weight': -0.0141378},
#  {'hashindex': '11979252',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f2099715132508010584')],
#   'original_feature_name': 'a^a1760747215799128656*f^f2099715132508010584',
#   'potential': -0.0141378,
#   'relative_potential': 0.020740155724133413,
#   'value': 1.0,
#   'weight': -0.0141378},
#  {'hashindex': '2546276',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f5035192394965831262')],
#   'original_feature_name': 'a^a1760747215799128656*f^f5035192394965831262',
#   'potential': -0.0140773,
#   'relative_potential': 0.02065140221076428,
#   'value': 1.0,
#   'weight': -0.0140773},
#  {'hashindex': '33426095',
#   'names': [('Item ID', 'a1760747215799128656')],
#   'original_feature_name': 'a^a1760747215799128656',
#   'potential': 0.0132487,
#   'relative_potential': 0.01943584582766246,
#   'value': 1.0,
#   'weight': 0.0132487},
#  {'hashindex': '30150445',
#   'names': [('Item property', 'b272')],
#   'original_feature_name': 'b^b272',
#   'potential': 0.0131667,
#   'relative_potential': 0.01931555180954232,
#   'value': 1.0,
#   'weight': 0.0131667},
#  {'hashindex': '17255489',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f16833477272344963305')],
#   'original_feature_name': 'b^b272*f^f16833477272344963305',
#   'potential': 0.0120934,
#   'relative_potential': 0.017741020472367343,
#   'value': 1.0,
#   'weight': 0.0120934},
#  {'hashindex': '31085757',
#   'names': [('Item tag', 'c49')],
#   'original_feature_name': 'c^c49',
#   'potential': 0.0119499,
#   'relative_potential': 0.017530505940657092,
#   'value': 1.0,
#   'weight': 0.0119499},
#  {'hashindex': '29613943',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f2868430111867810921')],
#   'original_feature_name': 'a^a1760747215799128656*f^f2868430111867810921',
#   'potential': -0.0117872,
#   'relative_potential': 0.017291825004704078,
#   'value': 1.0,
#   'weight': -0.0117872},
#  {'hashindex': '19294558',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f15901405900115419411')],
#   'original_feature_name': 'a^a1760747215799128656*f^f15901405900115419411',
#   'potential': -0.0114744,
#   'relative_potential': 0.01683294733558237,
#   'value': 1.0,
#   'weight': -0.0114744},
#  {'hashindex': '29586854',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature E', 'e243')],
#   'original_feature_name': 'a^a1760747215799128656*e^e243',
#   'potential': -0.0107759,
#   'relative_potential': 0.0158082476812297,
#   'value': 0.1,
#   'weight': -0.107759},
#  {'hashindex': '15440158',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f16445323628105595511')],
#   'original_feature_name': 'b^b272*f^f16445323628105595511',
#   'potential': -0.0104626,
#   'relative_potential': 0.015348636511997499,
#   'value': 1.0,
#   'weight': -0.0104626},
#  {'hashindex': '30834411',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f16833477272344963305')],
#   'original_feature_name': 'a^a1760747215799128656*f^f16833477272344963305',
#   'potential': 0.0102925,
#   'relative_potential': 0.015099099774409252,
#   'value': 1.0,
#   'weight': 0.0102925},
#  {'hashindex': '18453228',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature E', 'e262')],
#   'original_feature_name': 'a^a1760747215799128656*e^e262',
#   'potential': -0.009451880000000001,
#   'relative_potential': 0.013865910048651285,
#   'value': 0.2,
#   'weight': -0.0472594},
#  {'hashindex': '27154567',
#   'names': [('Item property', 'b272'), ('Request feature H', 'h69691')],
#   'original_feature_name': 'b^b272*h^h69691',
#   'potential': 0.00942961,
#   'relative_potential': 0.013833239953730116,
#   'value': 1.0,
#   'weight': 0.00942961},
#  {'hashindex': '13416483',
#   'names': [('Request feature F', 'f15901405900115419411')],
#   'original_feature_name': 'f^f15901405900115419411',
#   'potential': -0.00941212,
#   'relative_potential': 0.013807582119865222,
#   'value': 1.0,
#   'weight': -0.00941212},
#  {'hashindex': '21981741',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature H', 'h69691')],
#   'original_feature_name': 'a^a1760747215799128656*h^h69691',
#   'potential': 0.0089751,
#   'relative_potential': 0.013166473683293708,
#   'value': 1.0,
#   'weight': 0.0089751},
#  {'hashindex': '3845044',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f16445323628105595511')],
#   'original_feature_name': 'a^a1760747215799128656*f^f16445323628105595511',
#   'potential': -0.00892316,
#   'relative_potential': 0.013090277691816143,
#   'value': 1.0,
#   'weight': -0.00892316},
#  {'hashindex': '26200593',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f16833477272344963305')],
#   'original_feature_name': 'c^c49*f^f16833477272344963305',
#   'potential': 0.00887907,
#   'relative_potential': 0.013025597652073253,
#   'value': 1.0,
#   'weight': 0.00887907},
#  {'hashindex': '4950249',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f2868430111867810921')],
#   'original_feature_name': 'c^c22*f^f2868430111867810921',
#   'potential': 0.00862462,
#   'relative_potential': 0.01265231944584557,
#   'value': 1.0,
#   'weight': 0.00862462},
#  {'hashindex': '29925446',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e262')],
#   'original_feature_name': 'b^b272*e^e262',
#   'potential': -0.008494340000000001,
#   'relative_potential': 0.012461198657056645,
#   'value': 0.2,
#   'weight': -0.0424717},
#  {'hashindex': '16996999',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature I', 'iaab32')],
#   'original_feature_name': 'a^a1760747215799128656*i^iaab32',
#   'potential': 0.00845977,
#   'relative_potential': 0.012410484459417457,
#   'value': 1.0,
#   'weight': 0.00845977},
#  {'hashindex': '28507178',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f16445323628105595511')],
#   'original_feature_name': 'c^c22*f^f16445323628105595511',
#   'potential': 0.00841605,
#   'relative_potential': 0.012346347209756326,
#   'value': 1.0,
#   'weight': 0.00841605},
#  {'hashindex': '2690570',
#   'names': [('Request feature F', 'f2868430111867810921')],
#   'original_feature_name': 'f^f2868430111867810921',
#   'potential': -0.00822018,
#   'relative_potential': 0.012059005876473496,
#   'value': 1.0,
#   'weight': -0.00822018},
#  {'hashindex': '10470808',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e164')],
#   'original_feature_name': 'c^c22*e^e164',
#   'potential': -0.00815707,
#   'relative_potential': 0.011966423492527616,
#   'value': 0.1,
#   'weight': -0.0815707},
#  {'hashindex': '13629297',
#   'names': [('Item tag', 'c22')],
#   'original_feature_name': 'c^c22',
#   'potential': 0.00796425,
#   'relative_potential': 0.011683556509918766,
#   'value': 1.0,
#   'weight': 0.00796425},
#  {'hashindex': '7876543',
#   'names': [('Request feature F', 'f646294422815440915')],
#   'original_feature_name': 'f^f646294422815440915',
#   'potential': -0.00782882,
#   'relative_potential': 0.011484880669991804,
#   'value': 1.0,
#   'weight': -0.00782882},
#  {'hashindex': '16422082',
#   'names': [('Request feature F', 'f16392528256463451848')],
#   'original_feature_name': 'f^f16392528256463451848',
#   'potential': -0.00782882,
#   'relative_potential': 0.011484880669991804,
#   'value': 1.0,
#   'weight': -0.00782882},
#  {'hashindex': '15423255',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f5460200835877347079')],
#   'original_feature_name': 'c^c49*f^f5460200835877347079',
#   'potential': 0.00756359,
#   'relative_potential': 0.011095788201381985,
#   'value': 1.0,
#   'weight': 0.00756359},
#  {'hashindex': '30149401',
#   'names': [('Request feature F', 'f5035192394965831262')],
#   'original_feature_name': 'f^f5035192394965831262',
#   'potential': -0.00705291,
#   'relative_potential': 0.010346620528533277,
#   'value': 1.0,
#   'weight': -0.00705291},
#  {'hashindex': '14196446',
#   'names': [('Item property', 'b272'), ('Request feature D', 'd53')],
#   'original_feature_name': 'b^b272*d^d53',
#   'potential': -0.006957811,
#   'relative_potential': 0.010207110274518554,
#   'value': 0.17,
#   'weight': -0.0409283},
#  {'hashindex': '20904624',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f16347014626840415796')],
#   'original_feature_name': 'c^c22*f^f16347014626840415796',
#   'potential': 0.00695699,
#   'relative_potential': 0.01020590586733713,
#   'value': 1.0,
#   'weight': 0.00695699},
#  {'hashindex': '11419328',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f15901405900115419411')],
#   'original_feature_name': 'c^c22*f^f15901405900115419411',
#   'potential': 0.00691843,
#   'relative_potential': 0.010149338338816245,
#   'value': 1.0,
#   'weight': 0.00691843},
#  {'hashindex': '30566445',
#   'names': [('Item property', 'b272'), ('Request feature I', 'iaab32')],
#   'original_feature_name': 'b^b272*i^iaab32',
#   'potential': 0.00666488,
#   'relative_potential': 0.009777380432787442,
#   'value': 1.0,
#   'weight': 0.00666488},
#  {'hashindex': '29456149',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f16392528256463451848')],
#   'original_feature_name': 'b^b272*f^f16392528256463451848',
#   'potential': -0.00634171,
#   'relative_potential': 0.009303289971374196,
#   'value': 1.0,
#   'weight': -0.00634171},
#  {'hashindex': '21220456',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f646294422815440915')],
#   'original_feature_name': 'b^b272*f^f646294422815440915',
#   'potential': -0.00634171,
#   'relative_potential': 0.009303289971374196,
#   'value': 1.0,
#   'weight': -0.00634171},
#  {'hashindex': '26410690',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f646294422815440915')],
#   'original_feature_name': 'a^a1760747215799128656*f^f646294422815440915',
#   'potential': -0.00634171,
#   'relative_potential': 0.009303289971374196,
#   'value': 1.0,
#   'weight': -0.00634171},
#  {'hashindex': '3160498',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e429')],
#   'original_feature_name': 'c^c22*e^e429',
#   'potential': 0.00622041,
#   'relative_potential': 0.009125342844569643,
#   'value': 0.1,
#   'weight': 0.0622041},
#  {'hashindex': '20060137',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature E', 'e404')],
#   'original_feature_name': 'a^a1760747215799128656*e^e404',
#   'potential': 0.00617535,
#   'relative_potential': 0.009059239814612404,
#   'value': 0.3,
#   'weight': 0.0205845},
#  {'hashindex': '18017757',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f2868430111867810921')],
#   'original_feature_name': 'b^b272*f^f2868430111867810921',
#   'potential': -0.00607534,
#   'relative_potential': 0.008912525122512461,
#   'value': 1.0,
#   'weight': -0.00607534},
#  {'hashindex': '22557328',
#   'names': [('Request feature F', 'f5460200835877347079')],
#   'original_feature_name': 'f^f5460200835877347079',
#   'potential': -0.00591607,
#   'relative_potential': 0.008678875997317401,
#   'value': 1.0,
#   'weight': -0.00591607},
#  {'hashindex': '6496078',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f16445323628105595511')],
#   'original_feature_name': 'c^c49*f^f16445323628105595511',
#   'potential': -0.00579994,
#   'relative_potential': 0.008508513261655302,
#   'value': 1.0,
#   'weight': -0.00579994},
#  {'hashindex': '15305722',
#   'names': [('Request feature I', 'iaab32')],
#   'original_feature_name': 'i^iaab32',
#   'potential': -0.00577227,
#   'relative_potential': 0.00846792136554086,
#   'value': 1.0,
#   'weight': -0.00577227},
#  {'hashindex': '19665570',
#   'names': [('Item tag', 'c22'), ('Request feature D', 'd30')],
#   'original_feature_name': 'c^c22*d^d30',
#   'potential': -0.0056861640000000005,
#   'relative_potential': 0.008341603844513386,
#   'value': 0.33,
#   'weight': -0.0172308},
#  {'hashindex': '20881002',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f2099715132508010584')],
#   'original_feature_name': 'c^c22*f^f2099715132508010584',
#   'potential': -0.00531348,
#   'relative_potential': 0.007794876334158666,
#   'value': 1.0,
#   'weight': -0.00531348},
#  {'hashindex': '11971886',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f16347014626840415796')],
#   'original_feature_name': 'a^a1760747215799128656*f^f16347014626840415796',
#   'potential': -0.00526082,
#   'relative_potential': 0.007717624102522001,
#   'value': 1.0,
#   'weight': -0.00526082},
#  {'hashindex': '22736509',
#   'names': [('Item tag', 'c49'), ('Request feature I', 'iaab32')],
#   'original_feature_name': 'c^c49*i^iaab32',
#   'potential': -0.00524391,
#   'relative_potential': 0.0076928171287852735,
#   'value': 1.0,
#   'weight': -0.00524391},
#  {'hashindex': '26897293',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f2868430111867810921')],
#   'original_feature_name': 'c^c49*f^f2868430111867810921',
#   'potential': 0.00508733,
#   'relative_potential': 0.007463114234184642,
#   'value': 1.0,
#   'weight': 0.00508733},
#  {'hashindex': '24705906',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gccbb0')],
#   'original_feature_name': 'b^b272*g^gccbb0',
#   'potential': 0.004986464,
#   'relative_potential': 0.007315143789895542,
#   'value': 0.28,
#   'weight': 0.0178088},
#  {'hashindex': '8351390',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f5035192394965831262')],
#   'original_feature_name': 'c^c49*f^f5035192394965831262',
#   'potential': -0.0045604,
#   'relative_potential': 0.006690107807745053,
#   'value': 1.0,
#   'weight': -0.0045604},
#  {'hashindex': '23682182',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e429')],
#   'original_feature_name': 'b^b272*e^e429',
#   'potential': 0.00423777,
#   'relative_potential': 0.006216809526451135,
#   'value': 0.1,
#   'weight': 0.0423777},
#  {'hashindex': '498073',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g1b7db')],
#   'original_feature_name': 'a^a1760747215799128656*g^g1b7db',
#   'potential': 0.004018581,
#   'relative_potential': 0.005895259215015333,
#   'value': 0.09,
#   'weight': 0.0446509},
#  {'hashindex': '4397221',
#   'names': [('Request feature G', 'gccbb0')],
#   'original_feature_name': 'g^gccbb0',
#   'potential': -0.00394534,
#   'relative_potential': 0.005787814651830731,
#   'value': 0.28,
#   'weight': -0.0140905},
#  {'hashindex': '10765628',
#   'names': [('Item ID', 'a1760747215799128656'), ('Request feature D', 'd30')],
#   'original_feature_name': 'a^a1760747215799128656*d^d30',
#   'potential': -0.003909312,
#   'relative_potential': 0.005734961567869359,
#   'value': 0.33,
#   'weight': -0.0118464},
#  {'hashindex': '22812809',
#   'names': [('Request feature F', 'f2099715132508010584')],
#   'original_feature_name': 'f^f2099715132508010584',
#   'potential': -0.0036843,
#   'relative_potential': 0.005404868914146807,
#   'value': 1.0,
#   'weight': -0.0036843},
#  {'hashindex': '28216826',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f5035192394965831262')],
#   'original_feature_name': 'c^c22*f^f5035192394965831262',
#   'potential': -0.00344784,
#   'relative_potential': 0.005057982041894506,
#   'value': 1.0,
#   'weight': -0.00344784},
#  {'hashindex': '19226385',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g75702')],
#   'original_feature_name': 'a^a1760747215799128656*g^g75702',
#   'potential': -0.00341304,
#   'relative_potential': 0.005006930434204494,
#   'value': 0.02,
#   'weight': -0.170652},
#  {'hashindex': '6172003',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g1b7db')],
#   'original_feature_name': 'c^c49*g^g1b7db',
#   'potential': 0.0031984739999999998,
#   'relative_potential': 0.00469216206479027,
#   'value': 0.09,
#   'weight': 0.0355386},
#  {'hashindex': '20981270',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e262')],
#   'original_feature_name': 'c^c49*e^e262',
#   'potential': 0.0031761800000000002,
#   'relative_potential': 0.004659456761863802,
#   'value': 0.2,
#   'weight': 0.0158809},
#  {'hashindex': '695787',
#   'names': [('Item property', 'b272'), ('Request feature D', 'd266')],
#   'original_feature_name': 'b^b272*d^d266',
#   'potential': -0.0031218290000000004,
#   'relative_potential': 0.004579723832853463,
#   'value': 0.17,
#   'weight': -0.0183637},
#  {'hashindex': '7647461',
#   'names': [('Item ID', 'a1760747215799128656'), ('Request feature E', 'e81')],
#   'original_feature_name': 'a^a1760747215799128656*e^e81',
#   'potential': -0.003086,
#   'relative_potential': 0.004527162681936066,
#   'value': 0.1,
#   'weight': -0.03086},
#  {'hashindex': '10846799',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e81')],
#   'original_feature_name': 'b^b272*e^e81',
#   'potential': -0.003086,
#   'relative_potential': 0.004527162681936066,
#   'value': 0.1,
#   'weight': -0.03086},
#  {'hashindex': '13821477',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gb6297')],
#   'original_feature_name': 'c^c49*g^gb6297',
#   'potential': 0.00273568,
#   'relative_potential': 0.004013243164523284,
#   'value': 0.02,
#   'weight': 0.136784},
#  {'hashindex': '22838355',
#   'names': [('Request feature F', 'f16347014626840415796')],
#   'original_feature_name': 'f^f16347014626840415796',
#   'potential': 0.00251769,
#   'relative_potential': 0.0036934517863524345,
#   'value': 1.0,
#   'weight': 0.00251769},
#  {'hashindex': '6541639',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f5460200835877347079')],
#   'original_feature_name': 'b^b272*f^f5460200835877347079',
#   'potential': -0.00249503,
#   'relative_potential': 0.0036602095613450882,
#   'value': 1.0,
#   'weight': -0.00249503},
#  {'hashindex': '6791044',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f16347014626840415796')],
#   'original_feature_name': 'b^b272*f^f16347014626840415796',
#   'potential': 0.00245315,
#   'relative_potential': 0.003598771592090557,
#   'value': 1.0,
#   'weight': 0.00245315},
#  {'hashindex': '27904472',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gccbb0')],
#   'original_feature_name': 'a^a1760747215799128656*g^gccbb0',
#   'potential': 0.0024322564000000004,
#   'relative_potential': 0.0035681206762735456,
#   'value': 0.28,
#   'weight': 0.00868663},
#  {'hashindex': '16642502',
#   'names': [('Item tag', 'c49'), ('Request feature D', 'd30')],
#   'original_feature_name': 'c^c49*d^d30',
#   'potential': 0.0024310308,
#   'relative_potential': 0.003566322720802715,
#   'value': 0.33,
#   'weight': 0.00736676},
#  {'hashindex': '13480710',
#   'names': [('Item tag', 'c49'), ('Request feature D', 'd374')],
#   'original_feature_name': 'c^c49*d^d374',
#   'potential': -0.002373421,
#   'relative_potential': 0.003481809131472255,
#   'value': 0.17,
#   'weight': -0.0139613},
#  {'hashindex': '13602412',
#   'names': [('Request feature G', 'g75702')],
#   'original_feature_name': 'g^g75702',
#   'potential': -0.00231106,
#   'relative_potential': 0.003390325530691887,
#   'value': 0.02,
#   'weight': -0.115553},
#  {'hashindex': '31559548',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gd787f')],
#   'original_feature_name': 'b^b272*g^gd787f',
#   'potential': 0.00207468,
#   'relative_potential': 0.003043556018457264,
#   'value': 0.02,
#   'weight': 0.103734},
#  {'hashindex': '23831315',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e404')],
#   'original_feature_name': 'c^c49*e^e404',
#   'potential': 0.002048337,
#   'relative_potential': 0.0030049108316360577,
#   'value': 0.3,
#   'weight': 0.00682779},
#  {'hashindex': '5820222',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gd299a')],
#   'original_feature_name': 'c^c49*g^gd299a',
#   'potential': 0.00200644,
#   'relative_potential': 0.00294344792337777,
#   'value': 0.1,
#   'weight': 0.0200644},
#  {'hashindex': '31663427',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e404')],
#   'original_feature_name': 'b^b272*e^e404',
#   'potential': 0.001927551,
#   'relative_potential': 0.002827717742945089,
#   'value': 0.3,
#   'weight': 0.00642517},
#  {'hashindex': '21926977',
#   'names': [('Request feature D', 'd30')],
#   'original_feature_name': 'd^d30',
#   'potential': 0.0019053111,
#   'relative_potential': 0.002795091804730575,
#   'value': 0.33,
#   'weight': 0.00577367},
#  {'hashindex': '32537890',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gccbb0')],
#   'original_feature_name': 'c^c49*g^gccbb0',
#   'potential': 0.0018866344000000002,
#   'relative_potential': 0.002767693081703448,
#   'value': 0.28,
#   'weight': 0.00673798},
#  {'hashindex': '11723757',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f5460200835877347079')],
#   'original_feature_name': 'a^a1760747215799128656*f^f5460200835877347079',
#   'potential': -0.00178565,
#   'relative_potential': 0.002619548944588184,
#   'value': 1.0,
#   'weight': -0.00178565},
#  {'hashindex': '17843647',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature F', 'f16392528256463451848')],
#   'original_feature_name': 'a^a1760747215799128656*f^f16392528256463451848',
#   'potential': -0.00171161,
#   'relative_potential': 0.0025109322482270214,
#   'value': 1.0,
#   'weight': -0.00171161},
#  {'hashindex': '14397249',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature D', 'd266')],
#   'original_feature_name': 'a^a1760747215799128656*d^d266',
#   'potential': -0.0016834505000000001,
#   'relative_potential': 0.0024696222555044105,
#   'value': 0.17,
#   'weight': -0.00990265},
#  {'hashindex': '18632802',
#   'names': [('Item tag', 'c22'), ('Request feature D', 'd374')],
#   'original_feature_name': 'c^c22*d^d374',
#   'potential': 0.0016454997,
#   'relative_potential': 0.0024139484235181437,
#   'value': 0.17,
#   'weight': 0.00967941},
#  {'hashindex': '7064617',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gde9d9')],
#   'original_feature_name': 'c^c22*g^gde9d9',
#   'potential': -0.001627002,
#   'relative_potential': 0.0023868122935305713,
#   'value': 0.03,
#   'weight': -0.0542334},
#  {'hashindex': '26919260',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e243')],
#   'original_feature_name': 'c^c49*e^e243',
#   'potential': -0.0016069500000000002,
#   'relative_potential': 0.002357396005099534,
#   'value': 0.1,
#   'weight': -0.0160695},
#  {'hashindex': '15695118',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f2099715132508010584')],
#   'original_feature_name': 'c^c49*f^f2099715132508010584',
#   'potential': -0.00157192,
#   'relative_potential': 0.0023060069873586976,
#   'value': 1.0,
#   'weight': -0.00157192},
#  {'hashindex': '22280415',
#   'names': [('Item tag', 'c22'), ('Request feature D', 'd266')],
#   'original_feature_name': 'c^c22*d^d266',
#   'potential': 0.0015350915,
#   'relative_potential': 0.0022519795697204335,
#   'value': 0.17,
#   'weight': 0.00902995},
#  {'hashindex': '13650286',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gd299a')],
#   'original_feature_name': 'b^b272*g^gd299a',
#   'potential': 0.0015290700000000002,
#   'relative_potential': 0.0022431460278898186,
#   'value': 0.1,
#   'weight': 0.0152907},
#  {'hashindex': '4418086',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gc1e24')],
#   'original_feature_name': 'b^b272*g^gc1e24',
#   'potential': 0.0014928600000000002,
#   'relative_potential': 0.0021900259498882292,
#   'value': 0.01,
#   'weight': 0.149286},
#  {'hashindex': '9112857',
#   'names': [('Item tag', 'c22'), ('Request feature I', 'iaab32')],
#   'original_feature_name': 'c^c22*i^iaab32',
#   'potential': 0.00147591,
#   'relative_potential': 0.002165160296142663,
#   'value': 1.0,
#   'weight': 0.00147591},
#  {'hashindex': '7698326',
#   'names': [('Item property', 'b272'), ('Request feature D', 'd30')],
#   'original_feature_name': 'b^b272*d^d30',
#   'potential': -0.0014627646,
#   'relative_potential': 0.002145875991437828,
#   'value': 0.33,
#   'weight': -0.00443262},
#  {'hashindex': '14206612',
#   'names': [('Request feature E', 'e404')],
#   'original_feature_name': 'e^e404',
#   'potential': 0.0014540760000000001,
#   'relative_potential': 0.002133129813317844,
#   'value': 0.3,
#   'weight': 0.00484692},
#  {'hashindex': '30466691',
#   'names': [('Request feature G', 'g8eab9')],
#   'original_feature_name': 'g^g8eab9',
#   'potential': -0.00140227,
#   'relative_potential': 0.002057130399869892,
#   'value': 0.01,
#   'weight': -0.140227},
#  {'hashindex': '24964075',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g75702')],
#   'original_feature_name': 'c^c49*g^g75702',
#   'potential': -0.001389666,
#   'relative_potential': 0.0020386403290846935,
#   'value': 0.02,
#   'weight': -0.0694833},
#  {'hashindex': '4923960',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e243')],
#   'original_feature_name': 'c^c22*e^e243',
#   'potential': -0.00136201,
#   'relative_potential': 0.0019980689709733442,
#   'value': 0.1,
#   'weight': -0.0136201},
#  {'hashindex': '2729179',
#   'names': [('Request feature E', 'e243')],
#   'original_feature_name': 'e^e243',
#   'potential': -0.0013268800000000001,
#   'relative_potential': 0.0019465332532104106,
#   'value': 0.1,
#   'weight': -0.0132688},
#  {'hashindex': '21623109',
#   'names': [('Item tag', 'c49'),
#    ('Request feature F', 'f16392528256463451848')],
#   'original_feature_name': 'c^c49*f^f16392528256463451848',
#   'potential': -0.00127206,
#   'relative_potential': 0.0018661123010964328,
#   'value': 1.0,
#   'weight': -0.00127206},
#  {'hashindex': '5422929',
#   'names': [('Request feature E', 'e429')],
#   'original_feature_name': 'e^e429',
#   'potential': 0.00126071,
#   'relative_potential': 0.00184946184858834,
#   'value': 0.1,
#   'weight': 0.0126071},
#  {'hashindex': '9553266',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e262')],
#   'original_feature_name': 'c^c22*e^e262',
#   'potential': -0.001199944,
#   'relative_potential': 0.0017603181131604312,
#   'value': 0.2,
#   'weight': -0.00599972},
#  {'hashindex': '2203206',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gccbb0')],
#   'original_feature_name': 'c^c22*g^gccbb0',
#   'potential': 0.0011940404,
#   'relative_potential': 0.0017516575306558693,
#   'value': 0.28,
#   'weight': 0.00426443},
#  {'hashindex': '16246990',
#   'names': [('Item property', 'b272'),
#    ('Request feature F', 'f5035192394965831262')],
#   'original_feature_name': 'b^b272*f^f5035192394965831262',
#   'potential': -0.00114361,
#   'relative_potential': 0.0016776761227118937,
#   'value': 1.0,
#   'weight': -0.00114361},
#  {'hashindex': '25089665',
#   'names': [('Request feature D', 'd374')],
#   'original_feature_name': 'd^d374',
#   'potential': -0.0011297792,
#   'relative_potential': 0.0016573863360556005,
#   'value': 0.17,
#   'weight': -0.00664576},
#  {'hashindex': '1747292',
#   'names': [('Item tag', 'c22'), ('Request feature F', 'f646294422815440915')],
#   'original_feature_name': 'c^c22*f^f646294422815440915',
#   'potential': -0.00111039,
#   'relative_potential': 0.0016289423753710263,
#   'value': 1.0,
#   'weight': -0.00111039},
#  {'hashindex': '9966113',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f16392528256463451848')],
#   'original_feature_name': 'c^c22*f^f16392528256463451848',
#   'potential': -0.00111039,
#   'relative_potential': 0.0016289423753710263,
#   'value': 1.0,
#   'weight': -0.00111039},
#  {'hashindex': '32327908',
#   'names': [('Request feature G', 'g1b7db')],
#   'original_feature_name': 'g^g1b7db',
#   'potential': -0.001046853,
#   'relative_potential': 0.0015357335823307893,
#   'value': 0.09,
#   'weight': -0.0116317},
#  {'hashindex': '30100024',
#   'names': [('Item tag', 'c49'), ('Request feature F', 'f646294422815440915')],
#   'original_feature_name': 'c^c49*f^f646294422815440915',
#   'potential': 0.00103349,
#   'relative_potential': 0.0015161300583778692,
#   'value': 1.0,
#   'weight': 0.00103349},
#  {'hashindex': '17975052',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e243')],
#   'original_feature_name': 'b^b272*e^e243',
#   'potential': -0.00101072,
#   'relative_potential': 0.0014827264633462153,
#   'value': 0.1,
#   'weight': -0.0101072},
#  {'hashindex': '13656037',
#   'names': [('Item ID', 'a1760747215799128656'), ('Request feature E', 'e51')],
#   'original_feature_name': 'a^a1760747215799128656*e^e51',
#   'potential': 0.00100713,
#   'relative_potential': 0.0014774599325529064,
#   'value': 0.1,
#   'weight': 0.0100713},
#  {'hashindex': '2950175',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e81')],
#   'original_feature_name': 'c^c49*e^e81',
#   'potential': -0.000999616,
#   'relative_potential': 0.0014664368928924828,
#   'value': 0.1,
#   'weight': -0.00999616},
#  {'hashindex': '13781043',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g856b1')],
#   'original_feature_name': 'c^c49*g^g856b1',
#   'potential': 0.000966216,
#   'relative_potential': 0.0014174390855118397,
#   'value': 0.02,
#   'weight': 0.0483108},
#  {'hashindex': '30440137',
#   'names': [('Request feature F', 'f16445323628105595511')],
#   'original_feature_name': 'f^f16445323628105595511',
#   'potential': 0.000949166,
#   'relative_potential': 0.001392426731744176,
#   'value': 1.0,
#   'weight': 0.000949166},
#  {'hashindex': '93519',
#   'names': [('Item property', 'b272'), ('Request feature E', 'e51')],
#   'original_feature_name': 'b^b272*e^e51',
#   'potential': 0.0009260020000000001,
#   'relative_potential': 0.0013584451386254573,
#   'value': 0.1,
#   'weight': 0.00926002},
#  {'hashindex': '19572432',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g89fee')],
#   'original_feature_name': 'c^c49*g^g89fee',
#   'potential': 0.0009184490000000001,
#   'relative_potential': 0.0013473648859564154,
#   'value': 0.07,
#   'weight': 0.0131207},
#  {'hashindex': '6019201',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g69ddb')],
#   'original_feature_name': 'c^c49*g^g69ddb',
#   'potential': 0.00091586,
#   'relative_potential': 0.001343566822384305,
#   'value': 0.01,
#   'weight': 0.091586},
#  {'hashindex': '13057459',
#   'names': [('Item tag', 'c22'), ('Request feature H', 'h69691')],
#   'original_feature_name': 'c^c22*h^h69691',
#   'potential': -0.000899152,
#   'relative_potential': 0.0013190561826922154,
#   'value': 1.0,
#   'weight': -0.000899152},
#  {'hashindex': '26201607',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g1b7db')],
#   'original_feature_name': 'c^c22*g^g1b7db',
#   'potential': -0.0008802828,
#   'relative_potential': 0.00129137506212255,
#   'value': 0.09,
#   'weight': -0.00978092},
#  {'hashindex': '97220',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gd299a')],
#   'original_feature_name': 'a^a1760747215799128656*g^gd299a',
#   'potential': 0.0008598260000000001,
#   'relative_potential': 0.0012613649320020609,
#   'value': 0.1,
#   'weight': 0.00859826},
#  {'hashindex': '31163146',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g8a2bd')],
#   'original_feature_name': 'c^c49*g^g8a2bd',
#   'potential': 0.00085344,
#   'relative_potential': 0.0012519966685908995,
#   'value': 0.05,
#   'weight': 0.0170688},
#  {'hashindex': '24318506',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g89fee')],
#   'original_feature_name': 'a^a1760747215799128656*g^g89fee',
#   'potential': 0.000850535,
#   'relative_potential': 0.0012477350329489604,
#   'value': 0.07,
#   'weight': 0.0121505},
#  {'hashindex': '5951075',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g856b1')],
#   'original_feature_name': 'b^b272*g^g856b1',
#   'potential': 0.0008466999999999999,
#   'relative_potential': 0.0012421090871015121,
#   'value': 0.02,
#   'weight': 0.042335},
#  {'hashindex': '9174217',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g856b1')],
#   'original_feature_name': 'a^a1760747215799128656*g^g856b1',
#   'potential': 0.0008466999999999999,
#   'relative_potential': 0.0012421090871015121,
#   'value': 0.02,
#   'weight': 0.042335},
#  {'hashindex': '2404934',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gf0d48')],
#   'original_feature_name': 'c^c22*g^gf0d48',
#   'potential': 0.000825672,
#   'relative_potential': 0.0012112610064548006,
#   'value': 0.02,
#   'weight': 0.0412836},
#  {'hashindex': '158843',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g69ddb')],
#   'original_feature_name': 'a^a1760747215799128656*g^g69ddb',
#   'potential': 0.000793148,
#   'relative_potential': 0.0011635482912677338,
#   'value': 0.01,
#   'weight': 0.0793148},
#  {'hashindex': '13852369',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g69ddb')],
#   'original_feature_name': 'b^b272*g^g69ddb',
#   'potential': 0.000793148,
#   'relative_potential': 0.0011635482912677338,
#   'value': 0.01,
#   'weight': 0.0793148},
#  {'hashindex': '12206199',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e404')],
#   'original_feature_name': 'c^c22*e^e404',
#   'potential': 0.000787188,
#   'relative_potential': 0.0011548049699507089,
#   'value': 0.3,
#   'weight': 0.00262396},
#  {'hashindex': '19481819',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gc8829')],
#   'original_feature_name': 'c^c49*g^gc8829',
#   'potential': -0.0007870850000000001,
#   'relative_potential': 0.0011546538689279483,
#   'value': 0.05,
#   'weight': -0.0157417},
#  {'hashindex': '10101084',
#   'names': [('Request feature G', 'gc8829')],
#   'original_feature_name': 'g^gc8829',
#   'potential': -0.0007735900000000001,
#   'relative_potential': 0.0011348567009458591,
#   'value': 0.05,
#   'weight': -0.0154718},
#  {'hashindex': '16464952',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g1a16a')],
#   'original_feature_name': 'a^a1760747215799128656*g^g1a16a',
#   'potential': 0.0007518360000000001,
#   'relative_potential': 0.0011029435781387182,
#   'value': 0.02,
#   'weight': 0.0375918},
#  {'hashindex': '2756242',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g1a16a')],
#   'original_feature_name': 'b^b272*g^g1a16a',
#   'potential': 0.0007518360000000001,
#   'relative_potential': 0.0011029435781387182,
#   'value': 0.02,
#   'weight': 0.0375918},
#  {'hashindex': '9701372',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature D', 'd374')],
#   'original_feature_name': 'a^a1760747215799128656*d^d374',
#   'potential': 0.0007508339000000001,
#   'relative_potential': 0.0011014734972172768,
#   'value': 0.17,
#   'weight': 0.00441667},
#  {'hashindex': '25767002',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gd299a')],
#   'original_feature_name': 'c^c22*g^gd299a',
#   'potential': -0.000745178,
#   'relative_potential': 0.0010931762906674508,
#   'value': 0.1,
#   'weight': -0.00745178},
#  {'hashindex': '33351547',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e81')],
#   'original_feature_name': 'c^c22*e^e81',
#   'potential': 0.000712553,
#   'relative_potential': 0.0010453154084580651,
#   'value': 0.1,
#   'weight': 0.00712553},
#  {'hashindex': '29418623',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gfd512')],
#   'original_feature_name': 'c^c49*g^gfd512',
#   'potential': 0.0007115480000000001,
#   'relative_potential': 0.0010438410732359832,
#   'value': 0.02,
#   'weight': 0.0355774},
#  {'hashindex': '8202476',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gb9ea0')],
#   'original_feature_name': 'c^c22*g^gb9ea0',
#   'potential': 0.000705897,
#   'relative_potential': 0.00103555105498724,
#   'value': 0.01,
#   'weight': 0.0705897},
#  {'hashindex': '24580143',
#   'names': [('Item ID', 'a1760747215799128656'), ('Request feature D', 'd10')],
#   'original_feature_name': 'a^a1760747215799128656*d^d10',
#   'potential': 0.0006919867000000001,
#   'relative_potential': 0.0010151446418133793,
#   'value': 0.17,
#   'weight': 0.00407051},
#  {'hashindex': '14068531',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g1b7db')],
#   'original_feature_name': 'b^b272*g^g1b7db',
#   'potential': 0.0006855111,
#   'relative_potential': 0.0010056449351824182,
#   'value': 0.09,
#   'weight': 0.00761679},
#  {'hashindex': '31578838',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e429')],
#   'original_feature_name': 'c^c49*e^e429',
#   'potential': 0.0006679580000000001,
#   'relative_potential': 0.0009798945336035808,
#   'value': 0.1,
#   'weight': 0.00667958},
#  {'hashindex': '8526779',
#   'names': [('Item tag', 'c49'), ('Request feature D', 'd266')],
#   'original_feature_name': 'c^c49*d^d266',
#   'potential': 0.0006535225000000001,
#   'relative_potential': 0.0009587176519136626,
#   'value': 0.17,
#   'weight': 0.00384425},
#  {'hashindex': '27156888',
#   'names': [('Request feature E', 'e81')],
#   'original_feature_name': 'e^e81',
#   'potential': 0.000647132,
#   'relative_potential': 0.0009493427870015069,
#   'value': 0.1,
#   'weight': 0.00647132},
#  {'hashindex': '16730033',
#   'names': [('Item tag', 'c22'), ('Request feature D', 'd10')],
#   'original_feature_name': 'c^c22*d^d10',
#   'potential': 0.0005964484000000001,
#   'relative_potential': 0.0008749899346015799,
#   'value': 0.17,
#   'weight': 0.00350852},
#  {'hashindex': '10651842',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g1a16a')],
#   'original_feature_name': 'c^c49*g^g1a16a',
#   'potential': -0.0005539879999999999,
#   'relative_potential': 0.0008127005184187935,
#   'value': 0.02,
#   'weight': -0.0276994},
#  {'hashindex': '25836517',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g69ddb')],
#   'original_feature_name': 'c^c22*g^g69ddb',
#   'potential': 0.0005435009999999999,
#   'relative_potential': 0.0007973160871014042,
#   'value': 0.01,
#   'weight': 0.0543501},
#  {'hashindex': '25024370',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gf0d48')],
#   'original_feature_name': 'b^b272*g^gf0d48',
#   'potential': 0.000518544,
#   'relative_potential': 0.0007607041625864729,
#   'value': 0.02,
#   'weight': 0.0259272},
#  {'hashindex': '10861392',
#   'names': [('Request feature H', 'h69691')],
#   'original_feature_name': 'h^h69691',
#   'potential': 0.000516441,
#   'relative_potential': 0.0007576190611217575,
#   'value': 1.0,
#   'weight': 0.000516441},
#  {'hashindex': '20624499',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f5460200835877347079')],
#   'original_feature_name': 'c^c22*f^f5460200835877347079',
#   'potential': 0.00051642,
#   'relative_potential': 0.0007575882541171169,
#   'value': 1.0,
#   'weight': 0.00051642},
#  {'hashindex': '16295871',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gc8829')],
#   'original_feature_name': 'c^c22*g^gc8829',
#   'potential': 0.00051615,
#   'relative_potential': 0.0007571921640574531,
#   'value': 0.05,
#   'weight': 0.010323},
#  {'hashindex': '6170997',
#   'names': [('Item tag', 'c22'),
#    ('Request feature F', 'f16833477272344963305')],
#   'original_feature_name': 'c^c22*f^f16833477272344963305',
#   'potential': 0.000506048,
#   'relative_potential': 0.0007423725278251401,
#   'value': 1.0,
#   'weight': 0.000506048},
#  {'hashindex': '13781004',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gd9b64')],
#   'original_feature_name': 'a^a1760747215799128656*g^gd9b64',
#   'potential': -0.000497276,
#   'relative_potential': 0.0007295040018867267,
#   'value': 0.02,
#   'weight': -0.0248638},
#  {'hashindex': '11650396',
#   'names': [('Unknown feature None', 'Constant')],
#   'original_feature_name': 'Constant',
#   'potential': -0.000482438,
#   'relative_potential': 0.000707736652607865,
#   'value': 1.0,
#   'weight': -0.000482438},
#  {'hashindex': '633972',
#   'names': [('Item ID', 'a1760747215799128656'), ('Request feature D', 'd53')],
#   'original_feature_name': 'a^a1760747215799128656*d^d53',
#   'potential': 0.0004822577,
#   'relative_potential': 0.0007074721524680228,
#   'value': 0.17,
#   'weight': 0.00283681},
#  {'hashindex': '31685897',
#   'names': [('Request feature D', 'd53')],
#   'original_feature_name': 'd^d53',
#   'potential': -0.0004729383,
#   'relative_potential': 0.0006938005906086467,
#   'value': 0.17,
#   'weight': -0.00278199},
#  {'hashindex': '680046',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g8a2bd')],
#   'original_feature_name': 'c^c22*g^g8a2bd',
#   'potential': 0.00046104800000000004,
#   'relative_potential': 0.0006763575178811599,
#   'value': 0.05,
#   'weight': 0.00922096},
#  {'hashindex': '1408809',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gcb163')],
#   'original_feature_name': 'c^c22*g^gcb163',
#   'potential': -0.00043887099999999997,
#   'relative_potential': 0.0006438238539805453,
#   'value': 0.01,
#   'weight': -0.0438871},
#  {'hashindex': '13693013',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g5a110')],
#   'original_feature_name': 'c^c49*g^g5a110',
#   'potential': -0.000410631,
#   'relative_potential': 0.0006023957677401454,
#   'value': 0.01,
#   'weight': -0.0410631},
#  {'hashindex': '21899004',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e164')],
#   'original_feature_name': 'c^c49*e^e164',
#   'potential': -0.000405099,
#   'relative_potential': 0.0005942803225176987,
#   'value': 0.1,
#   'weight': -0.00405099},
#  {'hashindex': '16597883',
#   'names': [('Request feature E', 'e164')],
#   'original_feature_name': 'e^e164',
#   'potential': -0.000403758,
#   'relative_potential': 0.0005923130752213681,
#   'value': 0.1,
#   'weight': -0.00403758},
#  {'hashindex': '20020796',
#   'names': [('Request feature D', 'd266')],
#   'original_feature_name': 'd^d266',
#   'potential': 0.0003745134,
#   'relative_potential': 0.0005494112405589742,
#   'value': 0.17,
#   'weight': 0.00220302},
#  {'hashindex': '12779953',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g3bb58')],
#   'original_feature_name': 'a^a1760747215799128656*g^g3bb58',
#   'potential': 0.00036608400000000003,
#   'relative_potential': 0.0005370453088962679,
#   'value': 0.02,
#   'weight': 0.0183042},
#  {'hashindex': '3977110',
#   'names': [('Request feature F', 'f16833477272344963305')],
#   'original_feature_name': 'f^f16833477272344963305',
#   'potential': -0.000363257,
#   'relative_potential': 0.000532898099271565,
#   'value': 1.0,
#   'weight': -0.000363257},
#  {'hashindex': '26824837',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gfd512')],
#   'original_feature_name': 'a^a1760747215799128656*g^gfd512',
#   'potential': -0.000358376,
#   'relative_potential': 0.0005257376711929745,
#   'value': 0.02,
#   'weight': -0.0179188},
#  {'hashindex': '16975169',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gb6297')],
#   'original_feature_name': 'c^c22*g^gb6297',
#   'potential': 0.000346806,
#   'relative_potential': 0.0005087644786362668,
#   'value': 0.02,
#   'weight': 0.0173403},
#  {'hashindex': '5249166',
#   'names': [('Item tag', 'c49'), ('Request feature D', 'd53')],
#   'original_feature_name': 'c^c49*d^d53',
#   'potential': -0.00033566330000000004,
#   'relative_potential': 0.0004924181352739826,
#   'value': 0.17,
#   'weight': -0.00197449},
#  {'hashindex': '29662285',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gcb163')],
#   'original_feature_name': 'c^c49*g^gcb163',
#   'potential': 0.000319295,
#   'relative_potential': 0.00046840583555695915,
#   'value': 0.01,
#   'weight': 0.0319295},
#  {'hashindex': '25311216',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g8a2bd')],
#   'original_feature_name': 'a^a1760747215799128656*g^g8a2bd',
#   'potential': -0.00031877250000000005,
#   'relative_potential': 0.0004676393279414986,
#   'value': 0.05,
#   'weight': -0.00637545},
#  {'hashindex': '4535638',
#   'names': [('Item property', 'b272'), ('Request feature D', 'd374')],
#   'original_feature_name': 'b^b272*d^d374',
#   'potential': -0.0003164227,
#   'relative_potential': 0.00046419217082224593,
#   'value': 0.17,
#   'weight': -0.00186131},
#  {'hashindex': '5922933',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gb6297')],
#   'original_feature_name': 'b^b272*g^gb6297',
#   'potential': 0.00031562,
#   'relative_potential': 0.0004630146097448675,
#   'value': 0.02,
#   'weight': 0.015781},
#  {'hashindex': '608970',
#   'names': [('Request feature G', 'gde9d9')],
#   'original_feature_name': 'g^gde9d9',
#   'potential': 0.00031506599999999997,
#   'relative_potential': 0.000462201891622446,
#   'value': 0.03,
#   'weight': 0.0105022},
#  {'hashindex': '28864044',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature E', 'e429')],
#   'original_feature_name': 'a^a1760747215799128656*e^e429',
#   'potential': 0.000311659,
#   'relative_potential': 0.00045720382186957624,
#   'value': 0.1,
#   'weight': 0.00311659},
#  {'hashindex': '20614808',
#   'names': [('Request feature E', 'e51')],
#   'original_feature_name': 'e^e51',
#   'potential': -0.000310962,
#   'relative_potential': 0.00045618132271555507,
#   'value': 0.1,
#   'weight': -0.00310962},
#  {'hashindex': '20097309',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gde9d9')],
#   'original_feature_name': 'b^b272*g^gde9d9',
#   'potential': 0.00030377400000000004,
#   'relative_potential': 0.00044563652512716995,
#   'value': 0.03,
#   'weight': 0.0101258},
#  {'hashindex': '11937237',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g8a66c')],
#   'original_feature_name': 'b^b272*g^g8a66c',
#   'potential': 0.000300318,
#   'relative_potential': 0.00044056657236347225,
#   'value': 0.01,
#   'weight': 0.0300318},
#  {'hashindex': '32796091',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g75702')],
#   'original_feature_name': 'b^b272*g^g75702',
#   'potential': -0.000286188,
#   'relative_potential': 0.0004198378592410624,
#   'value': 0.02,
#   'weight': -0.0143094},
#  {'hashindex': '9590924',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gc1e24')],
#   'original_feature_name': 'a^a1760747215799128656*g^gc1e24',
#   'potential': 0.00027876,
#   'relative_potential': 0.0004089409815996428,
#   'value': 0.01,
#   'weight': 0.027876},
#  {'hashindex': '23660844',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gd787f')],
#   'original_feature_name': 'c^c49*g^gd787f',
#   'potential': 0.000274166,
#   'relative_potential': 0.0004022015825844729,
#   'value': 0.02,
#   'weight': 0.0137083},
#  {'hashindex': '22218074',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g8a2bd')],
#   'original_feature_name': 'b^b272*g^g8a2bd',
#   'potential': 0.000270441,
#   'relative_potential': 0.0003967370067613323,
#   'value': 0.05,
#   'weight': 0.00540882},
#  {'hashindex': '20486513',
#   'names': [('Request feature G', 'gd9b64')],
#   'original_feature_name': 'g^gd9b64',
#   'potential': -0.000267372,
#   'relative_potential': 0.00039223478308315283,
#   'value': 0.02,
#   'weight': -0.0133686},
#  {'hashindex': '28979021',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gde9d9')],
#   'original_feature_name': 'c^c49*g^gde9d9',
#   'potential': -0.0002665869,
#   'relative_potential': 0.0003910830412096636,
#   'value': 0.03,
#   'weight': -0.00888623},
#  {'hashindex': '21764637',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gcb163')],
#   'original_feature_name': 'b^b272*g^gcb163',
#   'potential': -0.00026450700000000003,
#   'relative_potential': 0.0003880318274500528,
#   'value': 0.01,
#   'weight': -0.0264507},
#  {'hashindex': '6874765',
#   'names': [('Request feature G', 'g8a2bd')],
#   'original_feature_name': 'g^g8a2bd',
#   'potential': -0.00024397,
# ...
#   'original_feature_name': 'g^gd787f',
#   'potential': 0.0001722916,
#   'relative_potential': 0.00025275181527253916,
#   'value': 0.02,
#   'weight': 0.00861458},
#  {'hashindex': '16266980',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g5b708')],
#   'original_feature_name': 'c^c49*g^g5b708',
#   'potential': 0.00017147069999999998,
#   'relative_potential': 0.00025154755479113883,
#   'value': 0.03,
#   'weight': 0.00571569},
#  {'hashindex': '24178721',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gc8829')],
#   'original_feature_name': 'a^a1760747215799128656*g^gc8829',
#   'potential': 0.000169313,
#   'relative_potential': 0.0002483822084143361,
#   'value': 0.05,
#   'weight': 0.00338626},
#  {'hashindex': '27378315',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gc8829')],
#   'original_feature_name': 'b^b272*g^gc8829',
#   'potential': 0.000169313,
#   'relative_potential': 0.0002483822084143361,
#   'value': 0.05,
#   'weight': 0.00338626},
#  {'hashindex': '228006',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gd9b64')],
#   'original_feature_name': 'b^b272*g^gd9b64',
#   'potential': 0.00016307019999999998,
#   'relative_potential': 0.0002392240194348187,
#   'value': 0.02,
#   'weight': 0.00815351},
#  {'hashindex': '11339919',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g75702')],
#   'original_feature_name': 'c^c22*g^g75702',
#   'potential': 0.000158914,
#   'relative_potential': 0.0002331268731163927,
#   'value': 0.02,
#   'weight': 0.0079457},
#  {'hashindex': '27160825',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g9a32e')],
#   'original_feature_name': 'a^a1760747215799128656*g^g9a32e',
#   'potential': 0.000157259,
#   'relative_potential': 0.00023069898775067522,
#   'value': 0.01,
#   'weight': 0.0157259},
#  {'hashindex': '20333435',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g5e800')],
#   'original_feature_name': 'a^a1760747215799128656*g^g5e800',
#   'potential': -0.00015635300000000003,
#   'relative_potential': 0.00022936988555046978,
#   'value': 0.01,
#   'weight': -0.0156353},
#  {'hashindex': '33474120',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gbdcb5')],
#   'original_feature_name': 'b^b272*g^gbdcb5',
#   'potential': 0.000152161,
#   'relative_potential': 0.00022322022062413275,
#   'value': 0.01,
#   'weight': 0.0152161},
#  {'hashindex': '9038623',
#   'names': [('Item tag', 'c49'), ('Request feature E', 'e51')],
#   'original_feature_name': 'c^c49*e^e51',
#   'potential': 0.000147624,
#   'relative_potential': 0.0002165644406215586,
#   'value': 0.1,
#   'weight': 0.00147624},
#  {'hashindex': '10986364',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gbdcb5')],
#   'original_feature_name': 'c^c22*g^gbdcb5',
#   'potential': 0.000143346,
#   'relative_potential': 0.00021028861367621753,
#   'value': 0.01,
#   'weight': 0.0143346},
#  {'hashindex': '10138955',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g3bb58')],
#   'original_feature_name': 'c^c49*g^g3bb58',
#   'potential': -0.00014096020000000002,
#   'relative_potential': 0.0002067886445490098,
#   'value': 0.02,
#   'weight': -0.00704801},
#  {'hashindex': '9130719',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gb6297')],
#   'original_feature_name': 'a^a1760747215799128656*g^gb6297',
#   'potential': -0.0001360634,
#   'relative_potential': 0.00019960503786692793,
#   'value': 0.02,
#   'weight': -0.00680317},
#  {'hashindex': '32854306',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gf0d48')],
#   'original_feature_name': 'c^c49*g^gf0d48',
#   'potential': 0.00013219420000000002,
#   'relative_potential': 0.00019392892061192245,
#   'value': 0.02,
#   'weight': 0.00660971},
#  {'hashindex': '28468320',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g8eab9')],
#   'original_feature_name': 'c^c22*g^g8eab9',
#   'potential': 0.000132113,
#   'relative_potential': 0.00019380980019397909,
#   'value': 0.01,
#   'weight': 0.0132113},
#  {'hashindex': '5797381',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g5a110')],
#   'original_feature_name': 'b^b272*g^g5a110',
#   'potential': 0.000130259,
#   'relative_potential': 0.0001910899817842871,
#   'value': 0.01,
#   'weight': 0.0130259},
#  {'hashindex': '6522628',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g8eab9')],
#   'original_feature_name': 'c^c49*g^g8eab9',
#   'potential': -0.00012980699999999999,
#   'relative_potential': 0.00019042689768440532,
#   'value': 0.01,
#   'weight': -0.0129807},
#  {'hashindex': '21971539',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g9a32e')],
#   'original_feature_name': 'b^b272*g^g9a32e',
#   'potential': 0.00012341700000000001,
#   'relative_potential': 0.00018105276627236017,
#   'value': 0.01,
#   'weight': 0.0123417},
#  {'hashindex': '6756223',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g8a66c')],
#   'original_feature_name': 'a^a1760747215799128656*g^g8a66c',
#   'potential': 0.000122715,
#   'relative_potential': 0.00018002293211723404,
#   'value': 0.01,
#   'weight': 0.0122715},
#  {'hashindex': '13364342',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gc1e24')],
#   'original_feature_name': 'c^c49*g^gc1e24',
#   'potential': 0.000119534,
#   'relative_potential': 0.00017535640441430512,
#   'value': 0.01,
#   'weight': 0.0119534},
#  {'hashindex': '32029958',
#   'names': [('Request feature G', 'g69ddb')],
#   'original_feature_name': 'g^g69ddb',
#   'potential': 0.00011532799999999999,
#   'relative_potential': 0.00016918620148487443,
#   'value': 0.01,
#   'weight': 0.0115328},
#  {'hashindex': '19834069',
#   'names': [('Item tag', 'c49'), ('Request feature D', 'd10')],
#   'original_feature_name': 'c^c49*d^d10',
#   'potential': 0.00011017972000000001,
#   'relative_potential': 0.00016163367358722127,
#   'value': 0.17,
#   'weight': 0.000648116},
#  {'hashindex': '17952069',
#   'names': [('Request feature G', 'g1a16a')],
#   'original_feature_name': 'g^g1a16a',
#   'potential': -0.0001078446,
#   'relative_potential': 0.00015820805203121263,
#   'value': 0.02,
#   'weight': -0.00539223},
#  {'hashindex': '21520943',
#   'names': [('Item property', 'b272'), ('Request feature G', 'gfd512')],
#   'original_feature_name': 'b^b272*g^gfd512',
#   'potential': 0.000107642,
#   'relative_potential': 0.00015791083778644263,
#   'value': 0.02,
#   'weight': 0.0053821},
#  {'hashindex': '1192731',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g3bb58')],
#   'original_feature_name': 'b^b272*g^g3bb58',
#   'potential': 0.000106135,
#   'relative_potential': 0.0001557000684534298,
#   'value': 0.02,
#   'weight': 0.00530675},
#  {'hashindex': '32866162',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gb9ea0')],
#   'original_feature_name': 'a^a1760747215799128656*g^gb9ea0',
#   'potential': 0.00010410900000000002,
#   'relative_potential': 0.0001527279260057297,
#   'value': 0.01,
#   'weight': 0.0104109},
#  {'hashindex': '22683538',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gd9b64')],
#   'original_feature_name': 'c^c22*g^gd9b64',
#   'potential': 0.000102504,
#   'relative_potential': 0.00015037339065106107,
#   'value': 0.02,
#   'weight': 0.0051252},
#  {'hashindex': '7385268',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g5b708')],
#   'original_feature_name': 'b^b272*g^g5b708',
#   'potential': -9.959219999999999e-05,
#   'relative_potential': 0.00014610177940761924,
#   'value': 0.03,
#   'weight': -0.00331974},
#  {'hashindex': '3814398',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g8eab9')],
#   'original_feature_name': 'a^a1760747215799128656*g^g8eab9',
#   'potential': 9.64485e-05,
#   'relative_potential': 0.0001414899708129328,
#   'value': 0.01,
#   'weight': 0.00964485},
#  {'hashindex': '23145908',
#   'names': [('Request feature G', 'g856b1')],
#   'original_feature_name': 'g^g856b1',
#   'potential': 9.5602e-05,
#   'relative_potential': 0.00014024815512587549,
#   'value': 0.02,
#   'weight': 0.0047801},
#  {'hashindex': '24341414',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g1a16a')],
#   'original_feature_name': 'c^c22*g^g1a16a',
#   'potential': -9.51296e-05,
#   'relative_potential': 0.0001395551442214858,
#   'value': 0.02,
#   'weight': -0.00475648},
#  {'hashindex': '24676849',
#   'names': [('Request feature G', 'gc1e24')],
#   'original_feature_name': 'g^gc1e24',
#   'potential': -8.962349999999999e-05,
#   'relative_potential': 0.00013147769430476243,
#   'value': 0.01,
#   'weight': -0.00896235},
#  {'hashindex': '23167906',
#   'names': [('Request feature G', 'gb6297')],
#   'original_feature_name': 'g^gb6297',
#   'potential': 7.98086e-05,
#   'relative_potential': 0.00011707923383589198,
#   'value': 0.02,
#   'weight': 0.00399043},
#  {'hashindex': '24526872',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gbdcb5')],
#   'original_feature_name': 'c^c49*g^gbdcb5',
#   'potential': 7.9452e-05,
#   'relative_potential': 0.00011655610155709147,
#   'value': 0.01,
#   'weight': 0.0079452},
#  {'hashindex': '7643524',
#   'names': [('Request feature G', 'g9a32e')],
#   'original_feature_name': 'g^g9a32e',
#   'potential': 7.815900000000001e-05,
#   'relative_potential': 0.00011465927027136779,
#   'value': 0.01,
#   'weight': 0.0078159},
#  {'hashindex': '20041907',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g57ebe')],
#   'original_feature_name': 'c^c49*g^g57ebe',
#   'potential': 7.50902e-05,
#   'relative_potential': 0.00011015733999323252,
#   'value': 0.01,
#   'weight': 0.00750902},
#  {'hashindex': '15401300',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g8eab9')],
#   'original_feature_name': 'b^b272*g^g8eab9',
#   'potential': -7.26616e-05,
#   'relative_potential': 0.00010659458325656696,
#   'value': 0.01,
#   'weight': -0.00726616},
#  {'hashindex': '21713763',
#   'names': [('Request feature G', 'g5b708')],
#   'original_feature_name': 'g^g5b708',
#   'potential': 7.265699999999999e-05,
#   'relative_potential': 0.00010658783505555045,
#   'value': 0.03,
#   'weight': 0.0024219},
#  {'hashindex': '16847665',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g5a110')],
#   'original_feature_name': 'c^c22*g^g5a110',
#   'potential': -6.310139999999999e-05,
#   'relative_potential': 9.25697677439794e-05,
#   'value': 0.01,
#   'weight': -0.00631014},
#  {'hashindex': '27076791',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'gcb163')],
#   'original_feature_name': 'a^a1760747215799128656*g^gcb163',
#   'potential': 6.24916e-05,
#   'relative_potential': 9.167519100922742e-05,
#   'value': 0.01,
#   'weight': 0.00624916},
#  {'hashindex': '1451879',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g9a32e')],
#   'original_feature_name': 'c^c22*g^g9a32e',
#   'potential': 6.17603e-05,
#   'relative_potential': 9.060237374762669e-05,
#   'value': 0.01,
#   'weight': 0.00617603},
#  {'hashindex': '9174262',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'gd9b64')],
#   'original_feature_name': 'c^c49*g^gd9b64',
#   'potential': -6.12632e-05,
#   'relative_potential': 8.987312793777886e-05,
#   'value': 0.02,
#   'weight': -0.00306316},
#  {'hashindex': '31945169',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g5e800')],
#   'original_feature_name': 'b^b272*g^g5e800',
#   'potential': 6.09088e-05,
#   'relative_potential': 8.935322305946449e-05,
#   'value': 0.01,
#   'weight': 0.00609088},
#  {'hashindex': '12920223',
#   'names': [('Request feature G', 'gbdcb5')],
#   'original_feature_name': 'g^gbdcb5',
#   'potential': -6.0546999999999995e-05,
#   'relative_potential': 8.882246237951488e-05,
#   'value': 0.01,
#   'weight': -0.0060547},
#  {'hashindex': '8566068',
#   'names': [('Request feature G', 'g57ebe')],
#   'original_feature_name': 'g^g57ebe',
#   'potential': -5.9213800000000006e-05,
#   'relative_potential': 8.686665768490791e-05,
#   'value': 0.01,
#   'weight': -0.00592138},
#  {'hashindex': '17017687',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g856b1')],
#   'original_feature_name': 'c^c22*g^g856b1',
#   'potential': 5.5177200000000004e-05,
#   'relative_potential': 8.094496459291078e-05,
#   'value': 0.02,
#   'weight': 0.00275886},
#  {'hashindex': '25295850',
#   'names': [('Item tag', 'c22'), ('Request feature D', 'd53')],
#   'original_feature_name': 'c^c22*d^d53',
#   'potential': -5.292525e-05,
#   'relative_potential': 7.764135344528087e-05,
#   'value': 0.17,
#   'weight': -0.000311325},
#  {'hashindex': '10077015',
#   'names': [('Request feature G', 'g89fee')],
#   'original_feature_name': 'g^g89fee',
#   'potential': 5.2258360000000005e-05,
#   'relative_potential': 7.666302566791329e-05,
#   'value': 0.07,
#   'weight': 0.000746548},
#  {'hashindex': '10338642',
#   'names': [('Request feature D', 'd10')],
#   'original_feature_name': 'd^d10',
#   'potential': 4.763179e-05,
#   'relative_potential': 6.987584645554616e-05,
#   'value': 0.17,
#   'weight': 0.000280187},
#  {'hashindex': '4600997',
#   'names': [('Request feature G', 'gf0d48')],
#   'original_feature_name': 'g^gf0d48',
#   'potential': 4.6450600000000006e-05,
#   'relative_potential': 6.814304046452995e-05,
#   'value': 0.02,
#   'weight': 0.00232253},
#  {'hashindex': '2076175',
#   'names': [('Request feature G', 'gb9ea0')],
#   'original_feature_name': 'g^gb9ea0',
#   'potential': 4.2266e-05,
#   'relative_potential': 6.200423133982816e-05,
#   'value': 0.01,
#   'weight': 0.0042266},
#  {'hashindex': '14455302',
#   'names': [('Request feature G', 'g5e800')],
#   'original_feature_name': 'g^g5e800',
#   'potential': 3.69985e-05,
#   'relative_potential': 5.4276807675830046e-05,
#   'value': 0.01,
#   'weight': 0.00369985},
#  {'hashindex': '27402368',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g89fee')],
#   'original_feature_name': 'b^b272*g^g89fee',
#   'potential': 2.9452290000000005e-05,
#   'relative_potential': 4.320651593828865e-05,
#   'value': 0.07,
#   'weight': 0.000420747},
#  {'hashindex': '18485010',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'gc1e24')],
#   'original_feature_name': 'c^c22*g^gc1e24',
#   'potential': 2.40166e-05,
#   'relative_potential': 3.523235750712434e-05,
#   'value': 0.01,
#   'weight': 0.00240166},
#  {'hashindex': '19517644',
#   'names': [('Request feature G', 'g3bb58')],
#   'original_feature_name': 'g^g3bb58',
#   'potential': -1.910586e-05,
#   'relative_potential': 2.8028300841962087e-05,
#   'value': 0.02,
#   'weight': -0.000955293},
#  {'hashindex': '22546555',
#   'names': [('Item tag', 'c22'), ('Request feature E', 'e51')],
#   'original_feature_name': 'c^c22*e^e51',
#   'potential': 1.88704e-05,
#   'relative_potential': 2.7682880969930764e-05,
#   'value': 0.1,
#   'weight': 0.000188704},
#  {'hashindex': '7862730',
#   'names': [('Request feature G', 'gcb163')],
#   'original_feature_name': 'g^gcb163',
#   'potential': 1.68555e-05,
#   'relative_potential': 2.4727022224683525e-05,
#   'value': 0.01,
#   'weight': 0.00168555},
#  {'hashindex': '14693335',
#   'names': [('Item tag', 'c22'), ('Request feature G', 'g57ebe')],
#   'original_feature_name': 'c^c22*g^g57ebe',
#   'potential': 9.43124e-06,
#   'relative_potential': 1.383563116409031e-05,
#   'value': 0.01,
#   'weight': 0.000943124},
#  {'hashindex': '23618633',
#   'names': [('Item ID', 'a1760747215799128656'),
#    ('Request feature G', 'g57ebe')],
#   'original_feature_name': 'a^a1760747215799128656*g^g57ebe',
#   'potential': -7.75786e-06,
#   'relative_potential': 1.1380782334311252e-05,
#   'value': 0.01,
#   'weight': -0.000775786},
#  {'hashindex': '28923619',
#   'names': [('Item property', 'b272'), ('Request feature G', 'g57ebe')],
#   'original_feature_name': 'b^b272*g^g57ebe',
#   'potential': -7.75786e-06,
#   'relative_potential': 1.1380782334311252e-05,
#   'value': 0.01,
#   'weight': -0.000775786},
#  {'hashindex': '4105093',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g8a66c')],
#   'original_feature_name': 'c^c49*g^g8a66c',
#   'potential': -7.433719999999999e-06,
#   'relative_potential': 1.0905268882683657e-05,
#   'value': 0.01,
#   'weight': -0.000743372},
#  {'hashindex': '24115073',
#   'names': [('Item tag', 'c49'), ('Request feature G', 'g5e800')],
#   'original_feature_name': 'c^c49*g^g5e800',
#   'potential': 2.83652e-06,
#   'relative_potential': 4.1611754668066394e-06,
#   'value': 0.01,
#   'weight': 0.000283652}]

# %% [markdown]
# You can also use HTML version of previous method:

# %%
formatter.print_human_readable_explanation(explanation_string, max_rows=100)
# Out:
#             <table>
#                 <thead>
#                     <tr>
#                         <th>Relative potential</th>
#                         <th>Potential</th>
#                         <th>Value</th>
#                         <th>Weight</th>
#                         <th>Feature name</th>
#                     </tr>
#                 </thead>
#                 <tbody>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 13.31189618965671%; height: 20px; background-color: green;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>0.0094</td>
#                     <td>
#                         1.0000
#                     </td>
#                     <td>
#                         0.0094
#                     </td>
#                     <td>
#                         Item ID: <i>a9357144256753103115</i>
#                         <span style="color: grey; margin-left: 10px; margin-right: 10px;">IN COMBINATION WITH</span>
#                         Request feature I: <i>i0708d</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 13.274443768709812%; height: 20px; background-color: green;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>0.0093</td>
#                     <td>
#                         1.0000
#                     </td>
#                     <td>
#                         0.0093
#                     </td>
#                     <td>
#                         Item property: <i>b515</i>
#                         <span style="color: grey; margin-left: 10px; margin-right: 10px;">IN COMBINATION WITH</span>
#                         Request feature I: <i>i0708d</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 10.25531777505023%; height: 20px; background-color: red;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>-0.0072</td>
#                     <td>
#                         0.5800
#                     </td>
#                     <td>
#                         -0.0124
#                     </td>
#                     <td>
#                         Item ID: <i>a9357144256753103115</i>
#                         <span style="color: grey; margin-left: 10px; margin-right: 10px;">IN COMBINATION WITH</span>
#                         Request feature G: <i>g57ebe</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 7.794985315735732%; height: 20px; background-color: red;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>-0.0055</td>
#                     <td>
#                         0.5800
#                     </td>
#                     <td>
#                         -0.0094
#                     </td>
#                     <td>
#                         Item tag: <i>c28</i>
#                         <span style="color: grey; margin-left: 10px; margin-right: 10px;">IN COMBINATION WITH</span>
#                         Request feature G: <i>g57ebe</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 6.539593820864951%; height: 20px; background-color: red;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>-0.0046</td>
#                     <td>
#                         1.0000
#                     </td>
#                     <td>
#                         -0.0046
#                     </td>
#                     <td>
#                         Item ID: <i>a9357144256753103115</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 5.721088443520673%; height: 20px; background-color: red;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>-0.0040</td>
#                     <td>
#                         1.0000
#                     </td>
#                     <td>
#                         -0.0040
#                     </td>
#                     <td>
#                         Item tag: <i>c28</i>
#                         <span style="color: grey; margin-left: 10px; margin-right: 10px;">IN COMBINATION WITH</span>
#                         Request feature I: <i>i0708d</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 5.409634509204938%; height: 20px; background-color: green;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>0.0038</td>
#                     <td>
#                         1.0000
#                     </td>
#                     <td>
#                         0.0038
#                     </td>
#                     <td>
#                         Item tag: <i>c35</i>
#                         <span style="color: grey; margin-left: 10px; margin-right: 10px;">IN COMBINATION WITH</span>
#                         Request feature H: <i>h69691</i>
#                     </td>
#                 </tr>
#
#                 <tr>
#                     <td>
#                         <div style="display: block; width: 100px; border: solid 1px;
#                                     -webkit-border-radius: 5px; -moz-border-radius: 5px; border-radius: 5px;">
#                             <div style="display: block; width: 4.885173166768051%; height: 20px; background-color: red;
#                                        overflow: hidden;"></div>
#                         </div>
#                     </td>
#                     <td>-0.0034</td>
#                     <td>
#                         0.5800
#                     </td>
#                     <td>
#                         -0.0059
#                     </td>
#                     <td>
#                         Request feature G: <i>g57ebe</i>
